# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')
df.head(10)
# Out:
#                     Name                              Job Titles   Department  \
# 0      AARON,  JEFFERY M                                SERGEANT       POLICE
# 1         AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)       POLICE
# 2    AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER         DAIS
# 3    ABAD JR,  VICENTE M                       CIVIL ENGINEER IV  WATER MGMNT
# 4      ABARCA,  EMMANUEL                        CONCRETE LABORER   TRANSPORTN
# 5     ABARCA,  FRANCES J                          POLICE OFFICER       POLICE
# 6      ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY         OEMC
# 7  ABBATACOLA,  ROBERT J                     ELECTRICAL MECHANIC     AVIATION
# 8  ABBATEMARCO,  JAMES J                       FIRE ENGINEER-EMT         FIRE
# 9       ABBATE,  TERRY M                          POLICE OFFICER       POLICE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# ...

# %%
df.describe()
# Out:
#        Typical Hours  Annual Salary  Hourly Rate
# count    7024.000000   24834.000000  7024.000000
# mean       36.025057   92413.141155    37.394469
# std         8.558911   21904.931072    12.785553
# min        10.000000   20400.000000     3.000000
# 25%        40.000000   80016.000000    30.680000
# 50%        40.000000   90024.000000    38.350000
# 75%        40.000000  101874.000000    47.560000
# max        40.000000  275004.000000   128.000000

# %%
df
# Out:
#                       Name                              Job Titles  \
# 0        AARON,  JEFFERY M                                SERGEANT
# 1           AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2      AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3      ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4        ABARCA,  EMMANUEL                        CONCRETE LABORER
# ...                    ...                                     ...
# 31853   ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 31854   ZYMANTAS,  LAURA C                          POLICE OFFICER
# 31855    ZYMANTAS,  MARK E                          POLICE OFFICER
# 31856  ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 31857  ZYSKOWSKI,  DARIUSZ                 CHIEF DATA BASE ANALYST
#
#         Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0           POLICE                 F           Salary            NaN
# ...

# %%
print(type(2))
print(type("Hello"))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print(2+2)
# Out:
# 4

# %%
print("Hello" + " World")
# Out:
# Hello World

# %%
print("2"+"2")
# Out:
# 22

# %%
type(df['Annual Salary'])
# Out:
# pandas.core.series.Series

# %%
df.plot.hist(bins=12, alpha=0.5)

# %%
df['Annual Salary'].plot.hist(bins=33, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>
