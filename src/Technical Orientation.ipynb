# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
tOne = pd.read_csv('2021-06-15-survey.csv', usecols = ['CPU Cycle Rate (in GHz)', 'CPU Number of Cores'])
tOne
# Out:
#     CPU Cycle Rate (in GHz)  CPU Number of Cores
# 0                      1.80                    4
# 1                      2.80                    4
# 2                      3.10                    2
# 3                      3.50                    4
# 4                      1.60                    2
# 5                      2.70                    2
# 6                      2.00                    8
# 7                      3.10                    2
# 8                      2.30                   16
# 9                      2.30                    8
# 10                     2.60                    6
# 11                     3.80                    8
# 12                     2.20                    6
# 13                     2.50                    4
# 14                     2.90                    5
# 15                     2.20                    4
# 16                     3.20                    8
# 17                     2.80                    4
# ...

# %%
tOne.plot()

# %%
surv = pd.read_csv('2021-06-15-survey.csv')
surv.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E33BA2F0F0>,
# ...
#       dtype=object)

# %%
# x = pd.read_csv('2021-06-15-survey.csv', usecols = ['CPU Cycle Rate (in GHz)'])
# y = pd.read_csv('2021-06-15-survey.csv', usecols = ['CPU Number of Cores'])
# df = pd.DataFrame({"cycle rate":x, "cpu cores": y})
# ax = df.plot.hist(columlocaln=["cycle rate"], by="cpu cores")
